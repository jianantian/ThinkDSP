# %%
import tensorflow as tf

# %%
from tensorflow.keras import applications

# %%
import tensorflow_datasets as tfds

# %%
model = applications.densenet.DenseNet121(weights='imagenet', include_top=False, pooling='avg')

# %%
model = applications.vgg19.VGG19(weights='imagenet', include_top=False, pooling='avg')
# Out:
# ...
# 80142336/80134624 [==============================] - 2316s 29us/step

# %%
ds_train, ds_test = tfds.load(name="cifar10", split=["train", "test"])
# Out:
# E0718 10:19:15.535208 140306643228480 registered.py:171] Failed to construct dataset cifar10
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/miniconda3/envs/tensorflow/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~/miniconda3/envs/tensorflow/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/miniconda3/envs/tensorflow/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
# ...
